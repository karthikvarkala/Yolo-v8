# %% [markdown]
# #Object Detection Using YOLO-V8 On Custom Data

# %%
#Lets connect with GPU
# And Iam using  the following command for checking whether I got GPU are not ?
# !nvidia-smi
# Out:
# Fri Dec 15 10:34:37 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# ####Ultralytics developed the yolo-v8

# %% [markdown]
# #Installation

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 7.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##YOLO _V8
#
# ##Task = Detection, Segmentation, Pose, Classification
#
# ##Modes = Train, Val, Predict

# %%
#predict

! yolo predict model = yolov8n.pt source ='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 283MB/s]
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 90.5MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 187.7ms
# Speed: 14.4ms preprocess, 187.7ms inference, 44.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
#Detect
# !yolo task=detect mode=predict model=yolov8n.pt source="images/1.jpg"
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images/1.jpg: 640x640 1 dog, 17.4ms
# Speed: 5.8ms preprocess, 17.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
#Detect
! yolo task = detect mode =predict model = yolov8n.pt source= 'images/1.jpg'
# Out:
# image 1/1 /content/images/1.jpg: 640x640 1 dog, 17.2ms
# Speed: 12.7ms preprocess, 17.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
#Segment
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="images/1.jpg"
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 125MB/s]
# Ultralytics YOLOv8.0.225 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/images/1.jpg: 640x640 1 dog, 11.0ms
# Speed: 3.3ms preprocess, 11.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
#classify
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="images/1.jpg"
# Out:
# ...
# 100% 5.28M/5.28M [00:00<00:00, 93.3MB/s]
# Ultralytics YOLOv8.0.225 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 755k/755k [00:00<00:00, 26.1MB/s]
# image 1/1 /content/images/1.jpg: 224x224 golden_retriever 0.22, Bedlington_terrier 0.12, Tibetan_terrier 0.08, miniature_poodle 0.07, standard_poodle 0.06, 3.8ms
# Speed: 8.8ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Mounting Google drive into colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import math

# %% [markdown]
# # Dataset Sample Images

# %%
directory_path = '/content/drive/MyDrive/yolo v8/data/train/images'

image_files = [f for f in os.listdir(directory_path) if f.endswith('.jpeg')]


num_images_to_display = 12
image_files = image_files[:num_images_to_display]

# Set the number of rows and columns for the subplots
rows = 4
cols = 3

# subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

axes = axes.flatten()

for i, image_file in enumerate(image_files):
    image_path = os.path.join(directory_path, image_file)
    img = mpimg.imread(image_path)
    axes[i].imshow(img)
    axes[i].axis('off')  # Turn off axis labels
    axes[i].set_title(f'Image {i+1}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# %cd /content/drive/MyDrive/yolo v8
# Out:
# /content/drive/MyDrive/yolo v8

# %%
! ls
# Out:
# data  data.yaml  runs  yolov8n.pt  yolov8s.pt

# %% [markdown]
# #Traning

# %%
# %cd /content/drive/MyDrive/yolo v8

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=224 plots=True  #batch= 8 or 4
# Out:
# /content/drive/MyDrive/yolo v8
# ...
# 100% 21.5M/21.5M [00:00<00:00, 188MB/s]
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					    P_curve.png		train_batch121.jpg
# confusion_matrix_normalized.png			    PR_curve.png	train_batch122.jpg
# confusion_matrix.png				    R_curve.png		train_batch1.jpg
# events.out.tfevents.1702290804.7e50d601bd56.3674.0  results.csv		train_batch2.jpg
# F1_curve.png					    results.png		val_batch0_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	val_batch0_pred.jpg
# labels.jpg					    train_batch120.jpg	weights

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
Image(filename='/content/drive/MyDrive/yolo v8/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/yolo v8/runs/detect/train/confusion_matrix_normalized.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/yolo v8/runs/detect/train/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/yolo v8/runs/detect/train/val_batch0_labels.jpg', width=800)

# %% [markdown]
# #Validate Custom Model

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/yolo v8/data/valid/labels.cache... 31 images, 0 backgrounds, 0 corrupt: 100% 31/31 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.53it/s]
#                    all         31        101      0.802      0.801      0.832      0.484
#                 Helmet         31         18      0.936          1      0.995      0.707
#                Goggles         31          9       0.56      0.444      0.548      0.225
#                 Jacket         31         14      0.749      0.857      0.847      0.552
#                 Gloves         31         52      0.769      0.703      0.775      0.418
#               Footwear         31          8      0.998          1      0.995      0.517
# ...

# %% [markdown]
# #Inference with Custom Model

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=data/test/images
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/31 /content/drive/MyDrive/yolo v8/data/test/images/1.jpeg: 192x224 1 Helmet, 1 Goggles, 2 Glovess, 94.6ms
# image 2/31 /content/drive/MyDrive/yolo v8/data/test/images/10.jpeg: 160x224 3 Glovess, 101.2ms
# image 3/31 /content/drive/MyDrive/yolo v8/data/test/images/11.jpeg: 224x224 2 Glovess, 9.1ms
# image 4/31 /content/drive/MyDrive/yolo v8/data/test/images/12.jpeg: 192x224 2 Glovess, 9.1ms
# image 5/31 /content/drive/MyDrive/yolo v8/data/test/images/13.jpeg: 128x224 1 Gloves, 58.0ms
# image 6/31 /content/drive/MyDrive/yolo v8/data/test/images/14(1).jpeg: 224x224 1 Jacket, 9.4ms
# image 7/31 /content/drive/MyDrive/yolo v8/data/test/images/14.jpg: 192x224 2 Helmets, 1 Goggles, 8.2ms
# image 8/31 /content/drive/MyDrive/yolo v8/data/test/images/15.jpeg: 224x224 (no detections), 8.5ms
# ...

# %% [markdown]
# #Predictions

# %%
directory_path = '/content/drive/MyDrive/yolo v8/runs/detect/predict'

image_files = [f for f in os.listdir(directory_path) if f.endswith('.jpeg')]


num_images_to_display = 12
image_files = image_files[:num_images_to_display]

# Set the number of rows and columns for the subplots
rows = 4
cols = 3

# subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

axes = axes.flatten()

for i, image_file in enumerate(image_files):
    image_path = os.path.join(directory_path, image_file)
    img = mpimg.imread(image_path)
    axes[i].imshow(img)
    axes[i].axis('off')  # Turn off axis labels
    axes[i].set_title(f'Image {i+1}')

# Adjust layout
plt.tight_layout()
plt.show()
